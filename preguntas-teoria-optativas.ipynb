# %% [markdown]
# ### Optativas: Optimización en la Industria / MHs Poblacionales
# ### UNSL - 2024
# # Preguntas teoria
# ## Conceptos generales sobre Metaheurísticas

# %% [raw]
# NOTA: los enunciados de los ejercicios están escritos en celdas de tipo Markdown y la respuesta/solución a cada uno de ellos debe ser presentado en una secuencia de una o mas celdas de tipo Code o Markdown, según corresponda e insertadas luego de cada enunciado. Si la solución o respuesta del ejercicio es texto y/o alguna expresión en Latex, entonces usar una celda Markdown.

# %% [markdown]
# $\mathbf{Ejercicio} \,\,1$: Defina con sus propias palabras lo que entiende por una metaheurística (MH). ¿Existen otros términos similares en la literatura para llamar a la misma clase de técnicas algorítmicas?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$ (celda Markdown ya que incluye código Latex)

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,2$: Una de las posibles clasificaciones de las MHs las divide en poblacionales y de trayectoria. Explicar las principales diferencias entre ambas clases y discutir posibles ventajas y desventajas de cada clase. ¿Existen otras posibilidades de clasificación para la familia de MHs?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
#
# $\mathbf{Ejercicio} \,\,3$: Dado un problema de optimización particular a resolver: ¿cuándo es recomendable aplicar MHs?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,4$:
# Explicar el concepto de “Quedar atascado en un óptimo local”.

# %% [markdown]
# +++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
#
# $\mathbf{Ejercicio} \,\,5$: Definir el concepto de “tamaño del espacio de búsqueda del problema”.

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,6$: Dado un problema particular y una codificación para las posibles soluciones de dicho problema. ¿Qué condiciones mínimas debería reunir dicha codificación para aplicar adecuadamente una MH particular?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,7$: ¿Por qué se define en general a una MH como un proceso o algoritmo estocástico? ¿qué implicancias tiene sobre el análisis del desempeño de este tipo de algoritmos?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,8$: Si se afirma que una determinada MH tiene poca capacidad de diversificar la búsqueda, ¿Qué implica dicha afirmación? De manera similar, si decimos que no tiene capacidad de intensificación, ¿cuál sería el efecto en su desempeño?

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$

# %% [markdown]
# _________________________
#
# $\mathbf{Ejercicio} \,\,9$:
# Realizar una breve investigación de los distintas metaheurísticas existentes resaltando la metáfora sobre la cual está basado su diseño y haciendo hincapié en las creadas en la última década, sean éstas poblacionales o de trayectoria (este ejercicio es para presentar hacia el final del curso).

# %% [markdown]
# ++++++++++++++++++++++++
#
# $\mathbf{Respuesta}$
